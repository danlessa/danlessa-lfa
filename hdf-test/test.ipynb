# %%
#%matplotlib inline
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
from inspect import *
from pyhdf.SD import *

# %%
path = "test.hdf"

# %%
sd = SD(path)

# %%
lat = sd.select("Latitude")[:]
lon = sd.select("Longitude")[:]
loc = (lon, lat)

d1 = sd.select('Surface_Pressure')
d2 = sd.select('Cloud_Fraction')
d3 = sd.select('Brightness_Temperature')
d4 = sd.select("Cloud_Mask_1km")

# %%
d4[5][6][0]
# Out:
# 121

# %%
sd.datasets()
# Out:
# {'Brightness_Temperature': (('Band_Number:mod06',
#    'Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (7, 406, 270),
#   22,
#   7),
#  'Brightness_Temperature_Difference': (('Band_Difference:mod06',
#    'Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (2, 406, 270),
#   22,
#   30),
#  'Cirrus_Reflectance': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   49),
#  'Cirrus_Reflectance_Flag': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   20,
#   50),
#  'Cloud_Effective_Emissivity': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   22),
#  'Cloud_Effective_Emissivity_Day': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   24),
#  'Cloud_Effective_Emissivity_Night': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   23),
#  'Cloud_Effective_Radius': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   34),
#  'Cloud_Effective_Radius_1621': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   36),
#  'Cloud_Effective_Radius_Uncertainty': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   41),
#  'Cloud_Effective_Radius_Uncertainty_1621': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   44),
#  'Cloud_Fraction': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   19),
#  'Cloud_Fraction_Day': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   21),
#  'Cloud_Fraction_Night': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   20),
#  'Cloud_Height_Method': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   11),
#  'Cloud_Mask_1km': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06',
#    'Cloud_Mask_1km_Num_Bytes:mod06'),
#   (2030, 1354, 2),
#   20,
#   53),
#  'Cloud_Mask_5km': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   51),
#  'Cloud_Multi_Layer_Flag': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   48),
#  'Cloud_Optical_Thickness': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   35),
#  'Cloud_Optical_Thickness_1621': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   37),
#  'Cloud_Optical_Thickness_Uncertainty': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   42),
#  'Cloud_Optical_Thickness_Uncertainty_1621': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   45),
#  'Cloud_Phase_Infrared': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   31),
#  'Cloud_Phase_Infrared_Day': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   33),
#  'Cloud_Phase_Infrared_Night': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   32),
#  'Cloud_Phase_Optical_Properties': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   47),
#  'Cloud_Top_Pressure': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   12),
#  'Cloud_Top_Pressure_Day': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   14),
#  'Cloud_Top_Pressure_From_Ratios': (('Band_Ratio:mod06',
#    'Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (5, 406, 270),
#   22,
#   27),
#  'Cloud_Top_Pressure_Infrared': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   25),
#  'Cloud_Top_Pressure_Night': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   13),
#  'Cloud_Top_Temperature': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   15),
#  'Cloud_Top_Temperature_Day': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   17),
#  'Cloud_Top_Temperature_Night': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   16),
#  'Cloud_Water_Path': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   39),
#  'Cloud_Water_Path_1621': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   40),
#  'Cloud_Water_Path_Uncertainty': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   43),
#  'Cloud_Water_Path_Uncertainty_1621': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2030, 1354),
#   22,
#   46),
#  'Effective_Radius_Difference': (('Radius_Difference:mod06',
#    'Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06'),
#   (2, 2030, 1354),
#   22,
#   38),
#  'Latitude': (('Cell_Along_Swath_5km:mod06', 'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   5,
#   0),
#  'Longitude': (('Cell_Along_Swath_5km:mod06', 'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   5,
#   1),
#  'Processing_Flag': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   20,
#   10),
#  'Quality_Assurance_1km': (('Cell_Along_Swath_1km:mod06',
#    'Cell_Across_Swath_1km:mod06',
#    'QA_Parameter_1km:mod06'),
#   (2030, 1354, 5),
#   20,
#   54),
#  'Quality_Assurance_5km': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06',
#    'QA_Parameter_5km:mod06'),
#   (406, 270, 10),
#   20,
#   52),
#  'Radiance_Variance': (('Band_Number:mod06',
#    'Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (7, 406, 270),
#   22,
#   29),
#  'Scan_Start_Time': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   6,
#   2),
#  'Sensor_Azimuth': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   6),
#  'Sensor_Zenith': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   5),
#  'Solar_Azimuth': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   4),
#  'Solar_Zenith': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   3),
#  'Spectral_Cloud_Forcing': (('Band_Forcing:mod06',
#    'Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (5, 406, 270),
#   22,
#   26),
#  'Surface_Pressure': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   9),
#  'Surface_Temperature': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   8),
#  'Surface_Type': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   28),
#  'Tropopause_Height': (('Cell_Along_Swath_5km:mod06',
#    'Cell_Across_Swath_5km:mod06'),
#   (406, 270),
#   22,
#   18)}

# %%
m = Basemap(projection='ortho',lon_0=np.min(lon),lat_0=np.min(lat),resolution='l')
x, y = m(lon,lat)
m.drawmapboundary()

m.drawcoastlines()
m.contourf(x,y,d2[:])
plt.colorbar()
plt.matshow(d2[:])
plt.show()

# %%
plt.show()

# %%
np.unique(d2[:])
# Out:
# array([  0,   4,   8,  12,  16,  20,  24,  28,  32,  36,  40,  44,  48,
#         52,  56,  60,  64,  68,  72,  76,  80,  84,  88,  92,  96, 100], dtype=int8)

# %%
d2.dimensions()
# Out:
# {'Cell_Across_Swath_5km:mod06': 270, 'Cell_Along_Swath_5km:mod06': 406}
